# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from bs4 import BeautifulSoup
import torchvision
from torchvision import transforms, datasets, models
import torch
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from PIL import Image
import matplotlib.pyplot as plt
from torchvision.models.detection.mask_rcnn import MaskRCNNPredictor
import matplotlib.patches as patches

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
def generate_box(obj):
    
    xmin = int(obj.find('xmin').text)
    ymin = int(obj.find('ymin').text)
    xmax = int(obj.find('xmax').text)
    ymax = int(obj.find('ymax').text)
    
    return [xmin, ymin, xmax, ymax]

def generate_label(obj):
    if obj.find('name').text == "with_mask":
        return 1
    elif obj.find('name').text == "mask_weared_incorrect":
        return 2
    return 0

def generate_target(image_id, file): 
    with open(file) as f:
        data = f.read()
        soup = BeautifulSoup(data, 'xml')
        objects = soup.find_all('object')

        num_objs = len(objects)

        # Bounding boxes for objects
        # In coco format, bbox = [xmin, ymin, width, height]
        # In pytorch, the input should be [xmin, ymin, xmax, ymax]
        boxes = []
        labels = []
        for i in objects:
            boxes.append(generate_box(i))
            labels.append(generate_label(i))
        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        # Labels (In my case, I only one class: target class or background)
        labels = torch.as_tensor(labels, dtype=torch.int64)
        # Tensorise img_id
        img_id = torch.tensor([image_id])
        # Annotation is in dictionary format
        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["image_id"] = img_id
        
        return target

# %%
image_dir = r"C:\Users\shash\Desktop\Code\VSC\datasets\face_masks\images"
# Directory of the mask images. The names should be same as in the image directory, but
imgs = list(sorted(os.listdir(image_dir)))
imgs
# Out:
# ['maksssksksss0.png',
#  'maksssksksss1.png',
#  'maksssksksss10.png',
#  'maksssksksss100.png',
#  'maksssksksss101.png',
#  'maksssksksss102.png',
#  'maksssksksss103.png',
#  'maksssksksss104.png',
#  'maksssksksss105.png',
#  'maksssksksss106.png',
#  'maksssksksss107.png',
#  'maksssksksss108.png',
#  'maksssksksss109.png',
#  'maksssksksss11.png',
#  'maksssksksss110.png',
#  'maksssksksss111.png',
#  'maksssksksss112.png',
#  'maksssksksss113.png',
#  'maksssksksss114.png',
#  'maksssksksss115.png',
#  'maksssksksss116.png',
#  'maksssksksss117.png',
#  'maksssksksss118.png',
#  'maksssksksss119.png',
#  'maksssksksss12.png',
#  'maksssksksss120.png',
#  'maksssksksss121.png',
#  'maksssksksss122.png',
#  'maksssksksss123.png',
#  'maksssksksss124.png',
#  'maksssksksss125.png',
#  'maksssksksss126.png',
#  'maksssksksss127.png',
#  'maksssksksss128.png',
#  'maksssksksss129.png',
#  'maksssksksss13.png',
#  'maksssksksss130.png',
#  'maksssksksss131.png',
#  'maksssksksss132.png',
#  'maksssksksss133.png',
#  'maksssksksss134.png',
#  'maksssksksss135.png',
#  'maksssksksss136.png',
#  'maksssksksss137.png',
#  'maksssksksss138.png',
#  'maksssksksss139.png',
#  'maksssksksss14.png',
#  'maksssksksss140.png',
#  'maksssksksss141.png',
#  'maksssksksss142.png',
#  'maksssksksss143.png',
#  'maksssksksss144.png',
#  'maksssksksss145.png',
#  'maksssksksss146.png',
#  'maksssksksss147.png',
#  'maksssksksss148.png',
#  'maksssksksss149.png',
#  'maksssksksss15.png',
#  'maksssksksss150.png',
#  'maksssksksss151.png',
#  'maksssksksss152.png',
#  'maksssksksss153.png',
#  'maksssksksss154.png',
#  'maksssksksss155.png',
#  'maksssksksss156.png',
#  'maksssksksss157.png',
#  'maksssksksss158.png',
#  'maksssksksss159.png',
#  'maksssksksss16.png',
#  'maksssksksss160.png',
#  'maksssksksss161.png',
#  'maksssksksss162.png',
#  'maksssksksss163.png',
#  'maksssksksss164.png',
#  'maksssksksss165.png',
#  'maksssksksss166.png',
#  'maksssksksss167.png',
#  'maksssksksss168.png',
#  'maksssksksss169.png',
#  'maksssksksss17.png',
#  'maksssksksss170.png',
#  'maksssksksss171.png',
#  'maksssksksss172.png',
#  'maksssksksss173.png',
#  'maksssksksss174.png',
#  'maksssksksss175.png',
#  'maksssksksss176.png',
#  'maksssksksss177.png',
#  'maksssksksss178.png',
#  'maksssksksss179.png',
#  'maksssksksss18.png',
#  'maksssksksss180.png',
#  'maksssksksss181.png',
#  'maksssksksss182.png',
#  'maksssksksss183.png',
#  'maksssksksss184.png',
#  'maksssksksss185.png',
#  'maksssksksss186.png',
#  'maksssksksss187.png',
#  'maksssksksss188.png',
#  'maksssksksss189.png',
#  'maksssksksss19.png',
#  'maksssksksss190.png',
#  'maksssksksss191.png',
#  'maksssksksss192.png',
#  'maksssksksss193.png',
#  'maksssksksss194.png',
#  'maksssksksss195.png',
#  'maksssksksss196.png',
#  'maksssksksss197.png',
#  'maksssksksss198.png',
#  'maksssksksss199.png',
#  'maksssksksss2.png',
#  'maksssksksss20.png',
#  'maksssksksss200.png',
#  'maksssksksss201.png',
#  'maksssksksss202.png',
#  'maksssksksss203.png',
#  'maksssksksss204.png',
#  'maksssksksss205.png',
#  'maksssksksss206.png',
#  'maksssksksss207.png',
#  'maksssksksss208.png',
#  'maksssksksss209.png',
#  'maksssksksss21.png',
#  'maksssksksss210.png',
#  'maksssksksss211.png',
#  'maksssksksss212.png',
#  'maksssksksss213.png',
#  'maksssksksss214.png',
#  'maksssksksss215.png',
#  'maksssksksss216.png',
#  'maksssksksss217.png',
#  'maksssksksss218.png',
#  'maksssksksss219.png',
#  'maksssksksss22.png',
#  'maksssksksss220.png',
#  'maksssksksss221.png',
#  'maksssksksss222.png',
#  'maksssksksss223.png',
#  'maksssksksss224.png',
#  'maksssksksss225.png',
#  'maksssksksss226.png',
#  'maksssksksss227.png',
#  'maksssksksss228.png',
#  'maksssksksss229.png',
#  'maksssksksss23.png',
#  'maksssksksss230.png',
#  'maksssksksss231.png',
#  'maksssksksss232.png',
#  'maksssksksss233.png',
#  'maksssksksss234.png',
#  'maksssksksss235.png',
#  'maksssksksss236.png',
#  'maksssksksss237.png',
#  'maksssksksss238.png',
#  'maksssksksss239.png',
#  'maksssksksss24.png',
#  'maksssksksss240.png',
#  'maksssksksss241.png',
#  'maksssksksss242.png',
#  'maksssksksss243.png',
#  'maksssksksss244.png',
#  'maksssksksss245.png',
#  'maksssksksss246.png',
#  'maksssksksss247.png',
#  'maksssksksss248.png',
#  'maksssksksss249.png',
#  'maksssksksss25.png',
#  'maksssksksss250.png',
#  'maksssksksss251.png',
#  'maksssksksss252.png',
#  'maksssksksss253.png',
#  'maksssksksss254.png',
#  'maksssksksss255.png',
#  'maksssksksss256.png',
#  'maksssksksss257.png',
#  'maksssksksss258.png',
#  'maksssksksss259.png',
#  'maksssksksss26.png',
#  'maksssksksss260.png',
#  'maksssksksss261.png',
#  'maksssksksss262.png',
#  'maksssksksss263.png',
#  'maksssksksss264.png',
#  'maksssksksss265.png',
#  'maksssksksss266.png',
#  'maksssksksss267.png',
#  'maksssksksss268.png',
#  'maksssksksss269.png',
#  'maksssksksss27.png',
#  'maksssksksss270.png',
#  'maksssksksss271.png',
#  'maksssksksss272.png',
#  'maksssksksss273.png',
#  'maksssksksss274.png',
#  'maksssksksss275.png',
#  'maksssksksss276.png',
#  'maksssksksss277.png',
#  'maksssksksss278.png',
#  'maksssksksss279.png',
#  'maksssksksss28.png',
#  'maksssksksss280.png',
#  'maksssksksss281.png',
#  'maksssksksss282.png',
#  'maksssksksss283.png',
#  'maksssksksss284.png',
#  'maksssksksss285.png',
#  'maksssksksss286.png',
#  'maksssksksss287.png',
#  'maksssksksss288.png',
#  'maksssksksss289.png',
#  'maksssksksss29.png',
#  'maksssksksss290.png',
#  'maksssksksss291.png',
#  'maksssksksss292.png',
#  'maksssksksss293.png',
#  'maksssksksss294.png',
#  'maksssksksss295.png',
#  'maksssksksss296.png',
#  'maksssksksss297.png',
#  'maksssksksss298.png',
#  'maksssksksss299.png',
#  'maksssksksss3.png',
#  'maksssksksss30.png',
#  'maksssksksss300.png',
#  'maksssksksss301.png',
#  'maksssksksss302.png',
#  'maksssksksss303.png',
#  'maksssksksss304.png',
#  'maksssksksss305.png',
#  'maksssksksss306.png',
#  'maksssksksss307.png',
#  'maksssksksss308.png',
#  'maksssksksss309.png',
#  'maksssksksss31.png',
#  'maksssksksss310.png',
#  'maksssksksss311.png',
#  'maksssksksss312.png',
#  'maksssksksss313.png',
#  'maksssksksss314.png',
#  'maksssksksss315.png',
#  'maksssksksss316.png',
#  'maksssksksss317.png',
#  'maksssksksss318.png',
#  'maksssksksss319.png',
#  'maksssksksss32.png',
#  'maksssksksss320.png',
#  'maksssksksss321.png',
#  'maksssksksss322.png',
#  'maksssksksss323.png',
#  'maksssksksss324.png',
#  'maksssksksss325.png',
#  'maksssksksss326.png',
#  'maksssksksss327.png',
#  'maksssksksss328.png',
#  'maksssksksss329.png',
#  'maksssksksss33.png',
#  'maksssksksss330.png',
#  'maksssksksss331.png',
#  'maksssksksss332.png',
#  'maksssksksss333.png',
#  'maksssksksss334.png',
#  'maksssksksss335.png',
#  'maksssksksss336.png',
#  'maksssksksss337.png',
#  'maksssksksss338.png',
#  'maksssksksss339.png',
#  'maksssksksss34.png',
#  'maksssksksss340.png',
#  'maksssksksss341.png',
#  'maksssksksss342.png',
#  'maksssksksss343.png',
#  'maksssksksss344.png',
#  'maksssksksss345.png',
#  'maksssksksss346.png',
#  'maksssksksss347.png',
#  'maksssksksss348.png',
#  'maksssksksss349.png',
#  'maksssksksss35.png',
#  'maksssksksss350.png',
#  'maksssksksss351.png',
#  'maksssksksss352.png',
#  'maksssksksss353.png',
#  'maksssksksss354.png',
#  'maksssksksss355.png',
#  'maksssksksss356.png',
#  'maksssksksss357.png',
#  'maksssksksss358.png',
#  'maksssksksss359.png',
#  'maksssksksss36.png',
#  'maksssksksss360.png',
#  'maksssksksss361.png',
#  'maksssksksss362.png',
#  'maksssksksss363.png',
#  'maksssksksss364.png',
#  'maksssksksss365.png',
#  'maksssksksss366.png',
#  'maksssksksss367.png',
#  'maksssksksss368.png',
#  'maksssksksss369.png',
#  'maksssksksss37.png',
#  'maksssksksss370.png',
#  'maksssksksss371.png',
#  'maksssksksss372.png',
#  'maksssksksss373.png',
#  'maksssksksss374.png',
#  'maksssksksss375.png',
#  'maksssksksss376.png',
#  'maksssksksss377.png',
#  'maksssksksss378.png',
#  'maksssksksss379.png',
#  'maksssksksss38.png',
#  'maksssksksss380.png',
#  'maksssksksss381.png',
#  'maksssksksss382.png',
#  'maksssksksss383.png',
#  'maksssksksss384.png',
#  'maksssksksss385.png',
#  'maksssksksss386.png',
#  'maksssksksss387.png',
#  'maksssksksss388.png',
#  'maksssksksss389.png',
#  'maksssksksss39.png',
#  'maksssksksss390.png',
#  'maksssksksss391.png',
#  'maksssksksss392.png',
#  'maksssksksss393.png',
#  'maksssksksss394.png',
#  'maksssksksss395.png',
#  'maksssksksss396.png',
#  'maksssksksss397.png',
#  'maksssksksss398.png',
#  'maksssksksss399.png',
#  'maksssksksss4.png',
#  'maksssksksss40.png',
#  'maksssksksss400.png',
#  'maksssksksss401.png',
#  'maksssksksss402.png',
#  'maksssksksss403.png',
#  'maksssksksss404.png',
#  'maksssksksss405.png',
#  'maksssksksss406.png',
#  'maksssksksss407.png',
#  'maksssksksss408.png',
#  'maksssksksss409.png',
#  'maksssksksss41.png',
#  'maksssksksss410.png',
#  'maksssksksss411.png',
#  'maksssksksss412.png',
#  'maksssksksss413.png',
#  'maksssksksss414.png',
#  'maksssksksss415.png',
#  'maksssksksss416.png',
#  'maksssksksss417.png',
#  'maksssksksss418.png',
#  'maksssksksss419.png',
#  'maksssksksss42.png',
#  'maksssksksss420.png',
#  'maksssksksss421.png',
#  'maksssksksss422.png',
#  'maksssksksss423.png',
#  'maksssksksss424.png',
#  'maksssksksss425.png',
#  'maksssksksss426.png',
#  'maksssksksss427.png',
#  'maksssksksss428.png',
#  'maksssksksss429.png',
#  'maksssksksss43.png',
#  'maksssksksss430.png',
#  'maksssksksss431.png',
#  'maksssksksss432.png',
#  'maksssksksss433.png',
#  'maksssksksss434.png',
#  'maksssksksss435.png',
#  'maksssksksss436.png',
#  'maksssksksss437.png',
#  'maksssksksss438.png',
#  'maksssksksss439.png',
#  'maksssksksss44.png',
#  'maksssksksss440.png',
#  'maksssksksss441.png',
#  'maksssksksss442.png',
#  'maksssksksss443.png',
#  'maksssksksss444.png',
#  'maksssksksss445.png',
#  'maksssksksss446.png',
#  'maksssksksss447.png',
#  'maksssksksss448.png',
#  'maksssksksss449.png',
#  'maksssksksss45.png',
#  'maksssksksss450.png',
#  'maksssksksss451.png',
#  'maksssksksss452.png',
#  'maksssksksss453.png',
#  'maksssksksss454.png',
#  'maksssksksss455.png',
#  'maksssksksss456.png',
#  'maksssksksss457.png',
#  'maksssksksss458.png',
#  'maksssksksss459.png',
#  'maksssksksss46.png',
#  'maksssksksss460.png',
#  'maksssksksss461.png',
#  'maksssksksss462.png',
#  'maksssksksss463.png',
#  'maksssksksss464.png',
#  'maksssksksss465.png',
#  'maksssksksss466.png',
#  'maksssksksss467.png',
#  'maksssksksss468.png',
#  'maksssksksss469.png',
#  'maksssksksss47.png',
#  'maksssksksss470.png',
#  'maksssksksss471.png',
#  'maksssksksss472.png',
#  'maksssksksss473.png',
#  'maksssksksss474.png',
#  'maksssksksss475.png',
#  'maksssksksss476.png',
#  'maksssksksss477.png',
#  'maksssksksss478.png',
#  'maksssksksss479.png',
#  'maksssksksss48.png',
#  'maksssksksss480.png',
#  'maksssksksss481.png',
#  'maksssksksss482.png',
#  'maksssksksss483.png',
#  'maksssksksss484.png',
#  'maksssksksss485.png',
#  'maksssksksss486.png',
#  'maksssksksss487.png',
#  'maksssksksss488.png',
#  'maksssksksss489.png',
#  'maksssksksss49.png',
#  'maksssksksss490.png',
#  'maksssksksss491.png',
#  'maksssksksss492.png',
#  'maksssksksss493.png',
#  'maksssksksss494.png',
#  'maksssksksss495.png',
#  'maksssksksss496.png',
#  'maksssksksss497.png',
#  'maksssksksss498.png',
#  'maksssksksss499.png',
#  'maksssksksss5.png',
#  'maksssksksss50.png',
#  'maksssksksss500.png',
#  'maksssksksss501.png',
#  'maksssksksss502.png',
#  'maksssksksss503.png',
#  'maksssksksss504.png',
#  'maksssksksss505.png',
#  'maksssksksss506.png',
#  'maksssksksss507.png',
#  'maksssksksss508.png',
#  'maksssksksss509.png',
#  'maksssksksss51.png',
#  'maksssksksss510.png',
#  'maksssksksss511.png',
#  'maksssksksss512.png',
#  'maksssksksss513.png',
#  'maksssksksss514.png',
#  'maksssksksss515.png',
#  'maksssksksss516.png',
#  'maksssksksss517.png',
#  'maksssksksss518.png',
#  'maksssksksss519.png',
#  'maksssksksss52.png',
#  'maksssksksss520.png',
#  'maksssksksss521.png',
#  'maksssksksss522.png',
#  'maksssksksss523.png',
#  'maksssksksss524.png',
#  'maksssksksss525.png',
#  'maksssksksss526.png',
#  'maksssksksss527.png',
#  'maksssksksss528.png',
#  'maksssksksss529.png',
#  'maksssksksss53.png',
#  'maksssksksss530.png',
#  'maksssksksss531.png',
#  'maksssksksss532.png',
#  'maksssksksss533.png',
#  'maksssksksss534.png',
#  'maksssksksss535.png',
#  'maksssksksss536.png',
#  'maksssksksss537.png',
#  'maksssksksss538.png',
#  'maksssksksss539.png',
#  'maksssksksss54.png',
#  'maksssksksss540.png',
#  'maksssksksss541.png',
#  'maksssksksss542.png',
#  'maksssksksss543.png',
#  'maksssksksss544.png',
#  'maksssksksss545.png',
#  'maksssksksss546.png',
#  'maksssksksss547.png',
#  'maksssksksss548.png',
#  'maksssksksss549.png',
#  'maksssksksss55.png',
#  'maksssksksss550.png',
#  'maksssksksss551.png',
#  'maksssksksss552.png',
#  'maksssksksss553.png',
#  'maksssksksss554.png',
#  'maksssksksss555.png',
#  'maksssksksss556.png',
#  'maksssksksss557.png',
#  'maksssksksss558.png',
#  'maksssksksss559.png',
#  'maksssksksss56.png',
#  'maksssksksss560.png',
#  'maksssksksss561.png',
#  'maksssksksss562.png',
#  'maksssksksss563.png',
#  'maksssksksss564.png',
#  'maksssksksss565.png',
#  'maksssksksss566.png',
#  'maksssksksss567.png',
#  'maksssksksss568.png',
#  'maksssksksss569.png',
#  'maksssksksss57.png',
#  'maksssksksss570.png',
#  'maksssksksss571.png',
#  'maksssksksss572.png',
#  'maksssksksss573.png',
#  'maksssksksss574.png',
#  'maksssksksss575.png',
#  'maksssksksss576.png',
#  'maksssksksss577.png',
#  'maksssksksss578.png',
#  'maksssksksss579.png',
#  'maksssksksss58.png',
#  'maksssksksss580.png',
#  'maksssksksss581.png',
#  'maksssksksss582.png',
#  'maksssksksss583.png',
#  'maksssksksss584.png',
#  'maksssksksss585.png',
#  'maksssksksss586.png',
#  'maksssksksss587.png',
#  'maksssksksss588.png',
#  'maksssksksss589.png',
#  'maksssksksss59.png',
#  'maksssksksss590.png',
#  'maksssksksss591.png',
#  'maksssksksss592.png',
#  'maksssksksss593.png',
#  'maksssksksss594.png',
#  'maksssksksss595.png',
#  'maksssksksss596.png',
#  'maksssksksss597.png',
#  'maksssksksss598.png',
#  'maksssksksss599.png',
#  'maksssksksss6.png',
#  'maksssksksss60.png',
#  'maksssksksss600.png',
#  'maksssksksss601.png',
#  'maksssksksss602.png',
#  'maksssksksss603.png',
#  'maksssksksss604.png',
#  'maksssksksss605.png',
#  'maksssksksss606.png',
#  'maksssksksss607.png',
#  'maksssksksss608.png',
#  'maksssksksss609.png',
#  'maksssksksss61.png',
#  'maksssksksss610.png',
#  'maksssksksss611.png',
#  'maksssksksss612.png',
#  'maksssksksss613.png',
#  'maksssksksss614.png',
#  'maksssksksss615.png',
#  'maksssksksss616.png',
#  'maksssksksss617.png',
#  'maksssksksss618.png',
#  'maksssksksss619.png',
#  'maksssksksss62.png',
#  'maksssksksss620.png',
#  'maksssksksss621.png',
#  'maksssksksss622.png',
#  'maksssksksss623.png',
#  'maksssksksss624.png',
#  'maksssksksss625.png',
#  'maksssksksss626.png',
#  'maksssksksss627.png',
#  'maksssksksss628.png',
#  'maksssksksss629.png',
#  'maksssksksss63.png',
#  'maksssksksss630.png',
#  'maksssksksss631.png',
#  'maksssksksss632.png',
#  'maksssksksss633.png',
#  'maksssksksss634.png',
#  'maksssksksss635.png',
#  'maksssksksss636.png',
#  'maksssksksss637.png',
#  'maksssksksss638.png',
#  'maksssksksss639.png',
#  'maksssksksss64.png',
#  'maksssksksss640.png',
#  'maksssksksss641.png',
#  'maksssksksss642.png',
#  'maksssksksss643.png',
#  'maksssksksss644.png',
#  'maksssksksss645.png',
#  'maksssksksss646.png',
#  'maksssksksss647.png',
#  'maksssksksss648.png',
#  'maksssksksss649.png',
#  'maksssksksss65.png',
#  'maksssksksss650.png',
#  'maksssksksss651.png',
#  'maksssksksss652.png',
#  'maksssksksss653.png',
#  'maksssksksss654.png',
#  'maksssksksss655.png',
#  'maksssksksss656.png',
#  'maksssksksss657.png',
#  'maksssksksss658.png',
#  'maksssksksss659.png',
#  'maksssksksss66.png',
#  'maksssksksss660.png',
#  'maksssksksss661.png',
#  'maksssksksss662.png',
#  'maksssksksss663.png',
#  'maksssksksss664.png',
#  'maksssksksss665.png',
#  'maksssksksss666.png',
#  'maksssksksss667.png',
#  'maksssksksss668.png',
#  'maksssksksss669.png',
#  'maksssksksss67.png',
#  'maksssksksss670.png',
#  'maksssksksss671.png',
#  'maksssksksss672.png',
#  'maksssksksss673.png',
#  'maksssksksss674.png',
#  'maksssksksss675.png',
#  'maksssksksss676.png',
#  'maksssksksss677.png',
#  'maksssksksss678.png',
#  'maksssksksss679.png',
#  'maksssksksss68.png',
#  'maksssksksss680.png',
#  'maksssksksss681.png',
#  'maksssksksss682.png',
#  'maksssksksss683.png',
#  'maksssksksss684.png',
#  'maksssksksss685.png',
#  'maksssksksss686.png',
#  'maksssksksss687.png',
#  'maksssksksss688.png',
#  'maksssksksss689.png',
#  'maksssksksss69.png',
#  'maksssksksss690.png',
#  'maksssksksss691.png',
#  'maksssksksss692.png',
#  'maksssksksss693.png',
#  'maksssksksss694.png',
#  'maksssksksss695.png',
#  'maksssksksss696.png',
#  'maksssksksss697.png',
#  'maksssksksss698.png',
#  'maksssksksss699.png',
#  'maksssksksss7.png',
#  'maksssksksss70.png',
#  'maksssksksss700.png',
#  'maksssksksss701.png',
#  'maksssksksss702.png',
#  'maksssksksss703.png',
#  'maksssksksss704.png',
#  'maksssksksss705.png',
#  'maksssksksss706.png',
#  'maksssksksss707.png',
#  'maksssksksss708.png',
#  'maksssksksss709.png',
#  'maksssksksss71.png',
#  'maksssksksss710.png',
#  'maksssksksss711.png',
#  'maksssksksss712.png',
#  'maksssksksss713.png',
#  'maksssksksss714.png',
#  'maksssksksss715.png',
#  'maksssksksss716.png',
#  'maksssksksss717.png',
#  'maksssksksss718.png',
#  'maksssksksss719.png',
#  'maksssksksss72.png',
#  'maksssksksss720.png',
#  'maksssksksss721.png',
#  'maksssksksss722.png',
#  'maksssksksss723.png',
#  'maksssksksss724.png',
#  'maksssksksss725.png',
#  'maksssksksss726.png',
#  'maksssksksss727.png',
#  'maksssksksss728.png',
#  'maksssksksss729.png',
#  'maksssksksss73.png',
#  'maksssksksss730.png',
#  'maksssksksss731.png',
#  'maksssksksss732.png',
#  'maksssksksss733.png',
#  'maksssksksss734.png',
#  'maksssksksss735.png',
#  'maksssksksss736.png',
#  'maksssksksss737.png',
#  'maksssksksss738.png',
#  'maksssksksss739.png',
#  'maksssksksss74.png',
#  'maksssksksss740.png',
#  'maksssksksss741.png',
#  'maksssksksss742.png',
#  'maksssksksss743.png',
#  'maksssksksss744.png',
#  'maksssksksss745.png',
#  'maksssksksss746.png',
#  'maksssksksss747.png',
#  'maksssksksss748.png',
#  'maksssksksss749.png',
#  'maksssksksss75.png',
#  'maksssksksss750.png',
#  'maksssksksss751.png',
#  'maksssksksss752.png',
#  'maksssksksss753.png',
#  'maksssksksss754.png',
#  'maksssksksss755.png',
#  'maksssksksss756.png',
#  'maksssksksss757.png',
#  'maksssksksss758.png',
#  'maksssksksss759.png',
#  'maksssksksss76.png',
#  'maksssksksss760.png',
#  'maksssksksss761.png',
#  'maksssksksss762.png',
#  'maksssksksss763.png',
#  'maksssksksss764.png',
#  'maksssksksss765.png',
#  'maksssksksss766.png',
#  'maksssksksss767.png',
#  'maksssksksss768.png',
#  'maksssksksss769.png',
#  'maksssksksss77.png',
#  'maksssksksss770.png',
#  'maksssksksss771.png',
#  'maksssksksss772.png',
#  'maksssksksss773.png',
#  'maksssksksss774.png',
#  'maksssksksss775.png',
#  'maksssksksss776.png',
#  'maksssksksss777.png',
#  'maksssksksss778.png',
#  'maksssksksss779.png',
#  'maksssksksss78.png',
#  'maksssksksss780.png',
#  'maksssksksss781.png',
#  'maksssksksss782.png',
#  'maksssksksss783.png',
#  'maksssksksss784.png',
#  'maksssksksss785.png',
#  'maksssksksss786.png',
#  'maksssksksss787.png',
#  'maksssksksss788.png',
#  'maksssksksss789.png',
#  'maksssksksss79.png',
#  'maksssksksss790.png',
#  'maksssksksss791.png',
#  'maksssksksss792.png',
#  'maksssksksss793.png',
#  'maksssksksss794.png',
#  'maksssksksss795.png',
#  'maksssksksss796.png',
#  'maksssksksss797.png',
#  'maksssksksss798.png',
#  'maksssksksss799.png',
#  'maksssksksss8.png',
#  'maksssksksss80.png',
#  'maksssksksss800.png',
#  'maksssksksss801.png',
#  'maksssksksss802.png',
#  'maksssksksss803.png',
#  'maksssksksss804.png',
#  'maksssksksss805.png',
#  'maksssksksss806.png',
#  'maksssksksss807.png',
#  'maksssksksss808.png',
#  'maksssksksss809.png',
#  'maksssksksss81.png',
#  'maksssksksss810.png',
#  'maksssksksss811.png',
#  'maksssksksss812.png',
#  'maksssksksss813.png',
#  'maksssksksss814.png',
#  'maksssksksss815.png',
#  'maksssksksss816.png',
#  'maksssksksss817.png',
#  'maksssksksss818.png',
#  'maksssksksss819.png',
#  'maksssksksss82.png',
#  'maksssksksss820.png',
#  'maksssksksss821.png',
#  'maksssksksss822.png',
#  'maksssksksss823.png',
#  'maksssksksss824.png',
#  'maksssksksss825.png',
#  'maksssksksss826.png',
#  'maksssksksss827.png',
#  'maksssksksss828.png',
#  'maksssksksss829.png',
#  'maksssksksss83.png',
#  'maksssksksss830.png',
#  'maksssksksss831.png',
#  'maksssksksss832.png',
#  'maksssksksss833.png',
#  'maksssksksss834.png',
#  'maksssksksss835.png',
#  'maksssksksss836.png',
#  'maksssksksss837.png',
#  'maksssksksss838.png',
#  'maksssksksss839.png',
#  'maksssksksss84.png',
#  'maksssksksss840.png',
#  'maksssksksss841.png',
#  'maksssksksss842.png',
#  'maksssksksss843.png',
#  'maksssksksss844.png',
#  'maksssksksss845.png',
#  'maksssksksss846.png',
#  'maksssksksss847.png',
#  'maksssksksss848.png',
#  'maksssksksss849.png',
#  'maksssksksss85.png',
#  'maksssksksss850.png',
#  'maksssksksss851.png',
#  'maksssksksss852.png',
#  'maksssksksss86.png',
#  'maksssksksss87.png',
#  'maksssksksss88.png',
#  'maksssksksss89.png',
#  'maksssksksss9.png',
#  'maksssksksss90.png',
#  'maksssksksss91.png',
#  'maksssksksss92.png',
#  'maksssksksss93.png',
#  'maksssksksss94.png',
#  'maksssksksss95.png',
#  'maksssksksss96.png',
#  'maksssksksss97.png',
#  'maksssksksss98.png',
#  'maksssksksss99.png']

# %%
labels_dir = r"C:\Users\shash\Desktop\Code\VSC\datasets\face_masks\annotations"
labels = list(sorted(os.listdir(labels_dir)))
labels
# Out:
# ['maksssksksss0.xml',
#  'maksssksksss1.xml',
#  'maksssksksss10.xml',
#  'maksssksksss100.xml',
#  'maksssksksss101.xml',
#  'maksssksksss102.xml',
#  'maksssksksss103.xml',
#  'maksssksksss104.xml',
#  'maksssksksss105.xml',
#  'maksssksksss106.xml',
#  'maksssksksss107.xml',
#  'maksssksksss108.xml',
#  'maksssksksss109.xml',
#  'maksssksksss11.xml',
#  'maksssksksss110.xml',
#  'maksssksksss111.xml',
#  'maksssksksss112.xml',
#  'maksssksksss113.xml',
#  'maksssksksss114.xml',
#  'maksssksksss115.xml',
#  'maksssksksss116.xml',
#  'maksssksksss117.xml',
#  'maksssksksss118.xml',
#  'maksssksksss119.xml',
#  'maksssksksss12.xml',
#  'maksssksksss120.xml',
#  'maksssksksss121.xml',
#  'maksssksksss122.xml',
#  'maksssksksss123.xml',
#  'maksssksksss124.xml',
#  'maksssksksss125.xml',
#  'maksssksksss126.xml',
#  'maksssksksss127.xml',
#  'maksssksksss128.xml',
#  'maksssksksss129.xml',
#  'maksssksksss13.xml',
#  'maksssksksss130.xml',
#  'maksssksksss131.xml',
#  'maksssksksss132.xml',
#  'maksssksksss133.xml',
#  'maksssksksss134.xml',
#  'maksssksksss135.xml',
#  'maksssksksss136.xml',
#  'maksssksksss137.xml',
#  'maksssksksss138.xml',
#  'maksssksksss139.xml',
#  'maksssksksss14.xml',
#  'maksssksksss140.xml',
#  'maksssksksss141.xml',
#  'maksssksksss142.xml',
#  'maksssksksss143.xml',
#  'maksssksksss144.xml',
#  'maksssksksss145.xml',
#  'maksssksksss146.xml',
#  'maksssksksss147.xml',
#  'maksssksksss148.xml',
#  'maksssksksss149.xml',
#  'maksssksksss15.xml',
#  'maksssksksss150.xml',
#  'maksssksksss151.xml',
#  'maksssksksss152.xml',
#  'maksssksksss153.xml',
#  'maksssksksss154.xml',
#  'maksssksksss155.xml',
#  'maksssksksss789.xml',
#  'maksssksksss79.xml',
#  'maksssksksss790.xml',
#  'maksssksksss791.xml',
#  'maksssksksss792.xml',
#  'maksssksksss793.xml',
#  'maksssksksss794.xml',
#  'maksssksksss795.xml',
#  'maksssksksss796.xml',
#  'maksssksksss797.xml',
#  'maksssksksss798.xml',
#  'maksssksksss799.xml',
#  'maksssksksss8.xml',
#  'maksssksksss80.xml',
#  'maksssksksss800.xml',
#  'maksssksksss801.xml',
#  'maksssksksss802.xml',
#  'maksssksksss803.xml',
#  'maksssksksss804.xml',
#  'maksssksksss805.xml',
#  'maksssksksss806.xml',
#  'maksssksksss807.xml',
#  'maksssksksss808.xml',
#  'maksssksksss809.xml',
#  'maksssksksss81.xml',
#  'maksssksksss810.xml',
#  'maksssksksss811.xml',
#  'maksssksksss812.xml',
#  'maksssksksss813.xml',
#  'maksssksksss814.xml',
#  'maksssksksss815.xml',
#  'maksssksksss816.xml',
#  'maksssksksss817.xml',
#  'maksssksksss818.xml',
#  'maksssksksss819.xml',
#  'maksssksksss82.xml',
#  'maksssksksss820.xml',
#  'maksssksksss821.xml',
#  'maksssksksss822.xml',
#  'maksssksksss823.xml',
#  'maksssksksss824.xml',
#  'maksssksksss825.xml',
#  'maksssksksss826.xml',
#  'maksssksksss827.xml',
#  'maksssksksss828.xml',
#  'maksssksksss829.xml',
#  'maksssksksss83.xml',
#  'maksssksksss830.xml',
#  'maksssksksss831.xml',
#  'maksssksksss832.xml',
#  'maksssksksss833.xml',
#  'maksssksksss834.xml',
#  'maksssksksss835.xml',
#  'maksssksksss836.xml',
#  'maksssksksss837.xml',
#  'maksssksksss838.xml',
#  'maksssksksss839.xml',
#  'maksssksksss84.xml',
#  'maksssksksss840.xml',
#  'maksssksksss841.xml',
#  'maksssksksss842.xml',
#  'maksssksksss843.xml',
#  'maksssksksss844.xml',
#  'maksssksksss845.xml',
#  'maksssksksss846.xml',
#  'maksssksksss847.xml',
#  'maksssksksss848.xml',
#  'maksssksksss849.xml',
#  'maksssksksss85.xml',
#  'maksssksksss850.xml',
#  'maksssksksss851.xml',
#  'maksssksksss852.xml',
#  'maksssksksss86.xml',
#  'maksssksksss87.xml',
#  'maksssksksss88.xml',
#  'maksssksksss89.xml',
#  'maksssksksss9.xml',
#  'maksssksksss90.xml',
#  'maksssksksss91.xml',
#  'maksssksksss92.xml',
#  'maksssksksss93.xml',
#  'maksssksksss94.xml',
#  'maksssksksss95.xml',
#  'maksssksksss96.xml',
#  'maksssksksss97.xml',
#  'maksssksksss98.xml',
#  'maksssksksss99.xml']

# %%
class MaskDataset(object):
    def __init__(self, transforms):
        self.transforms = transforms
        # load all image files, sorting them to
        # ensure that they are aligned
        self.imgs = list(sorted(os.listdir(image_dir)))
        self.labels = list(sorted(os.listdir(labels_dir)))

    def __getitem__(self, idx):
        # load images ad masks
        file_image = 'maksssksksss'+ str(idx) + '.png'
        file_label = 'maksssksksss'+ str(idx) + '.xml'
        img_path = os.path.join(image_dir, file_image)
        label_path = os.path.join(labels_dir, file_label)
        img = Image.open(img_path).convert("RGB")
        #Generate Label
        target = generate_target(idx, label_path)
        
        if self.transforms is not None:
            img = self.transforms(img)

        return img, target

    def __len__(self):
        return len(self.imgs)

# %%
data_transform = transforms.Compose([
        transforms.ToTensor(), 
    ])

# %%
def collate_fn(batch):
    return tuple(zip(*batch))

dataset = MaskDataset(data_transform)
data_loader = torch.utils.data.DataLoader(
 dataset, batch_size=4, collate_fn=collate_fn)

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# # Model

# %%
def get_model_instance_segmentation(num_classes):
    # load an instance segmentation model pre-trained pre-trained on COCO
    model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)
    # get number of input features for the classifier
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    # replace the pre-trained head with a new one
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

    return model

# %%
model = get_model_instance_segmentation(3)
# Out:
# c:\Users\shash\AppData\Local\Programs\Python\Python311\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\shash\AppData\Local\Programs\Python\Python311\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=FasterRCNN_ResNet50_FPN_Weights.COCO_V1`. You can also use `weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
for imgs, annotations in data_loader:
    imgs = list(img.to(device) for img in imgs)
    annotations = [{k: v.to(device) for k, v in t.items()} for t in annotations]
    print(annotations)
    break
# Out:
# ---------------------------------------------------------------------------
# FeatureNotFound                           Traceback (most recent call last)
# Cell In[11], line 2
#       1 device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
# ----> 2 for imgs, annotations in data_loader:
#       3     imgs = list(img.to(device) for img in imgs)
#       4     annotations = [{k: v.to(device) for k, v in t.items()} for t in annotations]
#
# File c:\Users\shash\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\utils\data\dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#     633 if self._dataset_kind == _DatasetKind.Iterable and \
#     634         self._IterableDataset_len_called is not None and \
#     635         self._num_yielded > self._IterableDataset_len_called:
#
# File c:\Users\shash\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\utils\data\dataloader.py:675, in _SingleProcessDataLoaderIter._next_data(self)
#     673 def _next_data(self):
#     674     index = self._next_index()  # may raise StopIteration
# --> 675     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     676     if self._pin_memory:
#     677         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File c:\Users\shash\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\utils\data\_utils\fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File c:\Users\shash\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\utils\data\_utils\fetch.py:51, in <listcomp>(.0)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# Cell In[5], line 17, in MaskDataset.__getitem__(self, idx)
#      15 img = Image.open(img_path).convert("RGB")
#      16 #Generate Label
# ---> 17 target = generate_target(idx, label_path)
#      19 if self.transforms is not None:
#      20     img = self.transforms(img)
#
# Cell In[2], line 20, in generate_target(image_id, file)
#      18 with open(file) as f:
#      19     data = f.read()
# ---> 20     soup = BeautifulSoup(data, 'xml')
#      21     objects = soup.find_all('object')
#      23     num_objs = len(objects)
#
# File c:\Users\shash\AppData\Local\Programs\Python\Python311\Lib\site-packages\bs4\__init__.py:250, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     248     builder_class = builder_registry.lookup(*features)
#     249     if builder_class is None:
# --> 250         raise FeatureNotFound(
#     251             "Couldn't find a tree builder with the features you "
#     252             "requested: %s. Do you need to install a parser library?"
#     253             % ",".join(features))
#     255 # At this point either we have a TreeBuilder instance in
#     256 # builder, or we have a builder_class that we can instantiate
#     257 # with the remaining **kwargs.
#     258 if builder is None:
#
# FeatureNotFound: Couldn't find a tree builder with the features you requested: xml. Do you need to install a parser library?

# %% [markdown]
# # Train Model

# %%
num_epochs = 25
model.to(device)
    
# parameters
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.005,
                                momentum=0.9, weight_decay=0.0005)

len_dataloader = len(data_loader)

for epoch in range(num_epochs):
    model.train()
    i = 0    
    epoch_loss = 0
    for imgs, annotations in data_loader:
        i += 1
        imgs = list(img.to(device) for img in imgs)
        annotations = [{k: v.to(device) for k, v in t.items()} for t in annotations]
        loss_dict = model([imgs[0]], [annotations[0]])
        losses = sum(loss for loss in loss_dict.values())        

        optimizer.zero_grad()
        losses.backward()
        optimizer.step() 
        print(f'\t Iteration: {i}/{len_dataloader}, Loss: {losses}')
        epoch_loss += losses
    print(epoch_loss)

# %%
for imgs, annotations in data_loader:
        imgs = list(img.to(device) for img in imgs)
        annotations = [{k: v.to(device) for k, v in t.items()} for t in annotations]
        break

# %%
model.eval()
preds = model(imgs)
preds

# %% [markdown]
# # Function to plot image

# %%
def plot_image(img_tensor, annotation):
    
    fig,ax = plt.subplots(1)
    img = img_tensor.cpu().data

    # Display the image
    ax.imshow(img.permute(1, 2, 0))
    
    for box in annotation["boxes"]:
        xmin, ymin, xmax, ymax = box

        # Create a Rectangle patch
        rect = patches.Rectangle((xmin,ymin),(xmax-xmin),(ymax-ymin),linewidth=1,edgecolor='r',facecolor='none')

        # Add the patch to the Axes
        ax.add_patch(rect)

    plt.show()

# %%
print("Prediction")
plot_image(imgs[2], preds[2])
print("Target")
plot_image(imgs[2], annotations[2])

# %%
torch.save(model.state_dict(),'model.pt')

# %%
model2 = get_model_instance_segmentation(3)

# %% [markdown]
# # Save Model

# %%
model2.load_state_dict(torch.load('model.pt'))
model2.eval()
model2.to(device)

# %% [markdown]
# # Load Model

# %%
pred2 = model2(imgs)

# %%
print("Predict with loaded model")
plot_image(imgs[3], pred2[3])
